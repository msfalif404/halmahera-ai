# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def test_api_health():
    """Test koneksi ke API"""
    print("🧪 Testing API Health")
    
    try:
        response = requests.get(f"{BASE_URL}/", timeout=5)
        if response.status_code == 200:
            print("✅ API is running")
        else:
            print(f"⚠️ API returned status: {response.status_code}")
    except requests.exceptions.ConnectionError:
        print("❌ Cannot connect to API. Make sure server is running.")
    except requests.exceptions.Timeout:
        print("❌ API request timeout")
    print("-" * 50)

# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def test_get_all_scholarships():
    """Test endpoint untuk mengambil semua beasiswa"""
    print("🧪 Testing GET /")
    
    response = requests.get(f"{BASE_URL}/", params={"limit": 10})
    
    print(f"Status Code: {response.status_code}")
    if response.status_code == 200:
        data = response.json()
        print(f"Count: {data.get('count', 0)}")
        print(f"Results: {len(data.get('results', []))} items")
        print("✅ Test passed")
    else:
        print(f"❌ Test failed: {response.text}")
    print("-" * 50)

test_get_all_scholarships()
# Out:
# 🧪 Testing GET /
# Status Code: 200
# Count: 10
# Results: 10 items
# ✅ Test passed
# --------------------------------------------------

# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def test_search_scholarships():
    """Test endpoint untuk pencarian beasiswa"""
    print("🧪 Testing GET /search")
    
    test_queries = [
        "computer science",
        "engineering scholarship",
        "PhD program"
    ]
    
    for query in test_queries:
        print(f"Query: '{query}'")
        response = requests.get(f"{BASE_URL}/search", params={"query": query, "k": 5})
        
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"Query: {data.get('query')}")
            print(f"Results: {data.get('results', [])}")
            print("✅ Test passed")
        else:
            print(f"❌ Test failed: {response.text}")
        print("-" * 30)
        
test_search_scholarships()
# Out:
# 🧪 Testing GET /search
# Query: 'computer science'
# Status Code: 200
# Query: computer science
# Results: [{'university': 'Any accredited university', 'degree': 'PhD', 'name': 'Facebook (Meta) PhD Fellowship', 'description': 'The Meta PhD Fellowship Program supports doctoral students conducting research in computer science and engineering fields relevant to Meta, including AI, AR/VR, data science, and computational social science.', 'location': 'Global', 'id': '52f43a73-9d74-47c3-82b5-8edd8fd6634c', 'deadline': '2026-09-15', 'fields': 'AI, Machine Learning, Computer Vision, Data Science, Engineering', 'url': 'https://research.facebook.com/fellowship/', 'tags': 'Tech, Fully Funded, Research, PhD'}, {'university': 'Any accredited university', 'degree': 'Undergraduate, Master’s, PhD', 'name': 'Google Women Techmakers Scholarship', 'description': 'The Google Women Techmakers Scholarship is designed to support women pursuing degrees in computer science, computer engineering, or closely related technical fields. Recipients receive financial support and access to a global community of women in tech.', 'location': 'Global', 'id': '8adc1cca-1673-4d19-845e-3b94acce929d', 'deadline': '2026-03-15', 'fields': 'Computer Science, Technology, Engineering', 'url': 'https://www.womentechmakers.com/scholars', 'tags': 'Women-only, Merit-based, Tech-focused'}, {'university': 'Partner universities worldwide', 'degree': 'PhD', 'name': 'Microsoft Research PhD Fellowship', 'description': 'The Microsoft Research PhD Fellowship supports exceptional doctoral students pursuing research in computer science, electrical engineering, or mathematics. It provides tuition and a living stipend for two academic years.', 'location': 'Global', 'id': '52e84182-ecb3-41e6-a46d-e7a6a5962778', 'deadline': '2026-06-01', 'fields': 'Computer Science, Data Science, AI, Cloud Computing, Mathematics', 'url': 'https://www.microsoft.com/en-us/research/academic-program/phd-fellowship/', 'tags': 'Tech, PhD, Research, Merit-based'}, {'university': 'Any accredited university', 'degree': 'PhD', 'name': 'Google PhD Fellowship', 'description': 'The Google PhD Fellowship Program recognizes outstanding graduate students pursuing innovative research in computer science and related fields. Fellows receive full tuition coverage, a generous stipend, and mentorship from a Google Research scientist.', 'location': 'Global', 'id': '83c8d148-baed-4197-b7c3-deb1d5a8576b', 'deadline': '2026-05-31', 'fields': 'Computer Science, Artificial Intelligence, Machine Learning, Human-Computer Interaction', 'url': 'https://research.google/outreach/phd-fellowship/', 'tags': 'STEM, Fully Funded, Research, Tech'}, {'university': 'German Universities', 'degree': 'Master (S-2)', 'name': 'DAAD Study Scholarships - Study scholarships for STEM disciplines', 'description': "The aim of the scholarship programme is to support the qualification and employability of young academics and future professionals from developing and emerging countries. It offers the opportunity to continue their academic and professional career in innovation-driving STEM fields in Germany with a Master’s degree in mathematics, computer science, natural sciences and engineering. The scholarship programme is aimed at high-achieving students from developing and emerging countries who would like to complete a Master’s degree in the STEM subjects at a German university. You can apply if you have completed your studies with a first degree recognised in Germany (e.g. Bachelor's degree) by the application deadline at the latest. If you already have a Master’s degree by the application deadline, you cannot apply. Funding is available for a complete Master's degree (full-time, on-campus) at a state or state-recognised university in Germany in the STEM subjects of mathematics, computer science, natural sciences and engineering. Study programmes with integrated stays outside Germany are excluded. Interdisciplinary degree programmes must have a designated STEM focus.", 'location': 'Germany', 'id': 'fdd87bb6-b9ac-4149-8291-27eee80d7dc5', 'deadline': '20 ...
# ✅ Test passed
# ------------------------------
# Query: 'engineering scholarship'
# Status Code: 200
# Query: engineering scholarship
# Results: [{'university': 'University of Tokyo', 'degree': 'Master (S-2), Doctoral (S-3)', 'name': 'MEXT University - University of Tokyo, Multidisciplinary Engineering', 'description': 'The MEXT (Monbukagakusho) Scholarship at the University of Tokyo for the Multidisciplinary Engineering program is a scholarship that can be obtained through the university recommendation route (U to U), where the university will recommend potential scholarship recipients to MEXT. The program offers Master of Engineering or Doctor of Engineering degrees for international students and covers study and living expenses.', 'location': 'Japan', 'id': '9f1ac823-5a91-42e1-a8fd-35ef32031419', 'deadline': '2026-08-13', 'fields': 'Engineering', 'url': '', 'tags': 'Fully Funded, Government'}, {'university': 'Kyoto University of Advanced Sciences (KUAS)', 'degree': 'Undergraduate (S-1)', 'name': 'Kyoto University of Advanced Sciences Scholarship', 'description': 'Kyoto University of Advanced Science (KUAS) offers several scholarships for international students, with the main ones being the Super KUAS-E Scholarship and the KUAS-E Scholarship. These are for students entering the Faculty of Engineering and Graduate School of Engineering programs. The university also has scholarships for currently enrolled students, as well as affiliations with external scholarships.', 'location': 'Japan', 'id': '05534bad-5f2a-4508-9052-c0da954140e6', 'deadline': '2026-03-06', 'fields': 'STEM', 'url': 'https://www.kuas.ac.jp/en/admission/scholarship/', 'tags': 'Merit-based'}, {'university': 'Partner Universities', 'degree': 'Master (S-2)', 'name': 'British Council Women in STEM Scholarships', 'description': "The British Council offers Women in STEM scholarships in partnership with UK universities to support women from various countries pursuing master's degrees in science, technology, engineering, and mathematics.", 'location': 'United Kingdom', 'id': '1f83ba18-b039-484f-aab3-8ff4f0b92972', 'deadline': '2026-05-02', 'fields': 'STEM (Science, Technology, Engineering, Mathematics)', 'url': 'https://www.britishcouncil.id/en/study-uk/women-in-STEM', 'tags': 'Fully Funded, Specific Group'}, {'university': 'German Universities (EPOS Programs)', 'degree': 'Master’s, PhD', 'name': 'DAAD Development-Related Postgraduate Courses (EPOS)', 'description': 'The DAAD EPOS scholarships offer funding for graduates from developing countries to pursue postgraduate studies in Germany in development-related fields such as economics, engineering, environmental management, and social sciences.', 'location': 'Germany', 'id': 'ccaea4b1-a3d2-4d9d-a152-71e39e546bea', 'deadline': '2025-10-15', 'fields': 'Sustainable Development, Economics, Engineering, Social Sciences, Environmental Studies', 'url': 'https://www.daad.de/en/study-and-research-in-germany/scholarships/epos-development-related-postgraduate-courses/', 'tags': 'Development, Fully Funded, Germany, Postgraduate'}, {'university': 'Any accredited university', 'degree': 'Undergraduate, Master’s, PhD', 'name': 'Google Women Techmakers Scholarship', 'description': 'The Google Women Techmakers Scholarship is designed to support women pursuing degrees in computer science, computer engineering, or closely related technical fields. Recipients receive financial support and access to a global community of women in tech.', 'location': 'Global', 'id': '8adc1cca-1673-4d19-845e-3b94acce929d', 'deadline': '2026-03-15', 'fields': 'Computer Science, Technology, Engineering', 'url': 'https://www.womentechmakers.com/scholars', 'tags': 'Women-only, Merit-based, Tech-focused'}]
# ✅ Test passed
# ------------------------------
# Query: 'PhD program'
# Status Code: 200
# Query: PhD program
# Results: [{'university': 'Partner universities worldwide', 'degree': 'PhD', 'name': 'IBM PhD Fellowship Program', 'description': 'The IBM PhD Fellowship honors exceptional PhD students who are addressing technical challenges important to IBM and the world. Research areas include AI, quantum computing, cloud, cybersecurity, and data analytics.', 'location': 'Global', 'id': 'd12fb6d6-753b-41ee-96ad-20480c0fb30c', 'deadline': '2025-10-31', 'fields': 'Artificial Intelligence, Quantum Computing, Cloud Computing, Data Science, Cybersecurity', 'url': 'https://research.ibm.com/university/awards/fellowships.html', 'tags': 'STEM, Research, Fully Funded, PhD'}, {'university': 'Any accredited university', 'degree': 'PhD', 'name': 'Google PhD Fellowship', 'description': 'The Google PhD Fellowship Program recognizes outstanding graduate students pursuing innovative research in computer science and related fields. Fellows receive full tuition coverage, a generous stipend, and mentorship from a Google Research scientist.', 'location': 'Global', 'id': '83c8d148-baed-4197-b7c3-deb1d5a8576b', 'deadline': '2026-05-31', 'fields': 'Computer Science, Artificial Intelligence, Machine Learning, Human-Computer Interaction', 'url': 'https://research.google/outreach/phd-fellowship/', 'tags': 'STEM, Fully Funded, Research, Tech'}, {'university': 'Any accredited university', 'degree': 'PhD', 'name': 'Facebook (Meta) PhD Fellowship', 'description': 'The Meta PhD Fellowship Program supports doctoral students conducting research in computer science and engineering fields relevant to Meta, including AI, AR/VR, data science, and computational social science.', 'location': 'Global', 'id': '52f43a73-9d74-47c3-82b5-8edd8fd6634c', 'deadline': '2026-09-15', 'fields': 'AI, Machine Learning, Computer Vision, Data Science, Engineering', 'url': 'https://research.facebook.com/fellowship/', 'tags': 'Tech, Fully Funded, Research, PhD'}, {'university': 'Partner universities worldwide', 'degree': 'PhD', 'name': 'Microsoft Research PhD Fellowship', 'description': 'The Microsoft Research PhD Fellowship supports exceptional doctoral students pursuing research in computer science, electrical engineering, or mathematics. It provides tuition and a living stipend for two academic years.', 'location': 'Global', 'id': '52e84182-ecb3-41e6-a46d-e7a6a5962778', 'deadline': '2026-06-01', 'fields': 'Computer Science, Data Science, AI, Cloud Computing, Mathematics', 'url': 'https://www.microsoft.com/en-us/research/academic-program/phd-fellowship/', 'tags': 'Tech, PhD, Research, Merit-based'}, {'university': 'Participating HK Universities', 'degree': 'Doctoral (S-3)', 'name': 'Hong Kong PhD Fellowship', 'description': "Established by the Research Grants Council (RGC) of Hong Kong in 2009, the Hong Kong PhD Fellowship Scheme (HKPFS) aims at attracting the best and brightest students in the world to pursue their PhD studies in Hong Kong's universities.Applicants should demonstrate outstanding qualities of academic performance, research ability / potential, communication and interpersonal skills, and leadership abilities.", 'location': 'Hong Kong', 'id': '8dc01303-02ae-462c-927f-40d50b8dacd0', 'deadline': '2026-12-01', 'fields': 'Research fields', 'url': 'https://cerg1.ugc.edu.hk/hkpfs/index.html', 'tags': 'Fully Funded, Research'}]
# ✅ Test passed
# ------------------------------

# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def test_create_application():
    """Test endpoint untuk membuat aplikasi"""
    print("🧪 Testing POST /applications")
    
    payload = {
        "scholarship_id": "cc8a1b56-723d-4381-bf84-7a64f028ce39",
        "user_id": "0LscQpIu4fleX4lQosl0f3a96u2YeqTc",
        "status": "on-progress"
    }
    
    response = requests.post(f"{BASE_URL}/applications", json=payload)
    
    print(f"Status Code: {response.status_code}")
    if response.status_code == 200:
        data = response.json()
        print(f"Application ID: {data.get('id')}")
        print("✅ Test passed")
    else:
        print(f"❌ Test failed: {response.text}")
    print("-" * 50)

# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def test_create_task():
    """Test endpoint untuk membuat task"""
    print("🧪 Testing POST /tasks")
    
    payload = {
        "name": "Prepare IELTS Certificate",
        "application_id": "8d09129d-4adb-4097-a42f-21e31552e6b5",
        "description": "Get IELTS certificate with minimum score 6.5",
        "status": "pending"
    }
    
    response = requests.post(f"{BASE_URL}/tasks", json=payload)
    
    print(f"Status Code: {response.status_code}")
    if response.status_code == 200:
        data = response.json()
        print(f"Task ID: {data.get('id')}")
        print("✅ Test passed")
    else:
        print(f"❌ Test failed: {response.text}")
    print("-" * 50)
